# %%
import sys
sys.path.insert(0, '/datasets/home/home-02/51/451/yuz530/HinDroid/')

# %%
# %autosave 60
# Out:
# Autosaving every 60 seconds

# %%
import pandas as pd
from glob import glob
import os
from tqdm import tqdm
from multiprocess import Pool

# %%
import numpy as np

# %%
from src.data.get_data import prep_dir
from src.features.smali_features import SmaliApp
from src.features.build_features import build_features, clean_features

# %%
import json

# %%
config = json.load(open('/datasets/home/51/451/yuz530/HinDroid/config/data-params.json'))

# %%
clean_features(**config)

# %%
# %%time
df, labels = build_features(**config)
# Out:
# Extracting features for class0
# 100%|██████████| 50/50 [02:07<00:00,  2.55s/it]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving raw features for class0
# 100%|██████████| 50/50 [00:27<00:00,  1.81it/s]
# Extracting features for class1
# 100%|██████████| 20/20 [00:10<00:00,  1.97it/s]
#  35%|███▌      | 7/20 [00:00<00:00, 41.88it/s]
# Saving raw features for class1
# 100%|██████████| 20/20 [00:01<00:00, 10.66it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Reading csv files for class0
# 100%|██████████| 50/50 [00:08<00:00,  5.56it/s]
#  30%|███       | 6/20 [00:00<00:00, 55.53it/s]
# Reading csv files for class1
# 100%|██████████| 20/20 [00:00<00:00, 26.82it/s]
# CPU times: user 55.2 s, sys: 7.74 s, total: 1min 2s
# Wall time: 3min 1s

# %%
raw_dir, proc_dir, raw_classes_dirs, interim_classes_dirs = \
    prep_dir(config['data_dir'], config['data_classes'])

# %%
class FeatureBuilder():
    
    def __init__(self, agg_df, labels):
        self.df = agg_df
        self.labels = pd.Series(labels).sort_index()
        self.out = pd.DataFrame()
    
    def _flatten_col_names(df):
        df.columns = ['.'.join(col).strip() for col in df.columns.values]
        return df
    
    def _simple_aggregations(df):
        out = df.groupby('package').agg({
            'call': 'size',
            'library': 'nunique',
            'code_block_id': ['mean', 'std', 'median', 'max', 'nunique'],
        })
        return FeatureBuilder._flatten_col_names(out)
    
    def _invoke_counts_by_type(df):
        out = df.groupby('package')['invocation'].value_counts().unstack(fill_value=0)
        out.columns = [col + '.count' for col in out.columns.values]
        return out
        
    def numerical_features(self):
        features = [
            FeatureBuilder._simple_aggregations(self.df),
            FeatureBuilder._invoke_counts_by_type(self.df)
        ]
        out = pd.concat(features, axis=1)
        return out
    
    def _top5_library(df):
        out = df.groupby('package')['library'].apply(
            lambda s: s.value_counts().iloc[:5]
        ).unstack(fill_value=0).clip(upper=1)
        out.columns = ['top5.' + col for col in out.columns.values]
        return out
    
    def categorical_features(self):
        features = [
            FeatureBuilder._top5_library(self.df)
        ]
        out = pd.concat(features, axis=1)
        return out
        
        
    def build(self):
        self.out = pd.concat([
            self.numerical_features(),
            self.categorical_features()
        ], axis=1)

# %%
fb = FeatureBuilder(df, labels)

# %%
df.groupby(['package', 'method_name']).ngroups
# Out:
# 318373

# %%
fb.build()

# %%
fb.out
# Out:
#                                   call.size  library.nunique  \
# package
# 09f502a90a61229d76c71907b4f3f74f        551               79
# 115e0149ccfeaec1fa1fbd4abbecafeb        780              118
# 177af9700bcc8b7c8c131b662e8cdda8      28604             1738
# 17d083988dd5e6d9c2517899ae30bb02      20053             1379
# 23ee5fe81d5017edcc97f3c007748438      61457             2444
# ...                                     ...              ...
# net.n2works.getsureill                96242             4899
# nl.mxmx.texttotifinagh                16208              982
# org.adventistas.advcountdown          91609             4122
# photography.blackgallery.android     213059            10809
# se.konferensappen.svenskaMoten6       20471             1411
#
#                                   code_block_id.mean  code_block_id.std  \
# package
# 09f502a90a61229d76c71907b4f3f74f           64.201452          24.529264
# 115e0149ccfeaec1fa1fbd4abbecafeb           91.141026          38.839396
# 177af9700bcc8b7c8c131b662e8cdda8         6408.225388        3994.201302
# 17d083988dd5e6d9c2517899ae30bb02         4393.452750        2926.900600
# 23ee5fe81d5017edcc97f3c007748438         7512.191614        4182.714417
# ...                                              ...                ...
# net.n2works.getsureill                  14770.938800        8343.441718
# nl.mxmx.texttotifinagh                   3407.646471        2141.520545
# org.adventistas.advcountdown            15546.552566        8647.964873
# photography.blackgallery.android        32274.402635       18753.661904
# se.konferensappen.svenskaMoten6          4562.745884        2969.141212
#
#                                   code_block_id.median  code_block_id.max  \
# package
# 09f502a90a61229d76c71907b4f3f74f                  60.0                100
# 115e0149ccfeaec1fa1fbd4abbecafeb                 108.5                142
# 177af9700bcc8b7c8c131b662e8cdda8                6817.0              12145
# 17d083988dd5e6d9c2517899ae30bb02                3930.0               8899
# 23ee5fe81d5017edcc97f3c007748438                7783.0              13737
# ...                                                ...                ...
# net.n2works.getsureill                         15079.0              29118
# nl.mxmx.texttotifinagh                          3728.0               6621
# org.adventistas.advcountdown                   15913.0              30125
# photography.blackgallery.android               32624.0              63189
# se.konferensappen.svenskaMoten6                 4223.0               9034
#
#                                   code_block_id.nunique  invoke-direct.count  \
# package
# 09f502a90a61229d76c71907b4f3f74f                     84                  117
# 115e0149ccfeaec1fa1fbd4abbecafeb                    119                  164
# 177af9700bcc8b7c8c131b662e8cdda8                   8793                 5328
# 17d083988dd5e6d9c2517899ae30bb02                   6463                 3770
# 23ee5fe81d5017edcc97f3c007748438                   9459                 9741
# ...                                                 ...                  ...
# net.n2works.getsureill                            20415                15629
# nl.mxmx.texttotifinagh                             4660                 2809
# org.adventistas.advcountdown                      23559                16873
# photography.blackgallery.android                  48903                42696
# se.konferensappen.svenskaMoten6                    6496                 3853
#
#                                   invoke-interface.count  invoke-static.count  \
# package
# 09f502a90a61229d76c71907b4f3f74f                      18                   68
# 115e0149ccfeaec1fa1fbd4abbecafeb                      39                  143
# 177af9700bcc8b7c8c131b662e8cdda8                    2124                 5270
# 17d083988dd5e6d9c2517899ae30bb02                    1559                 4020
# 23ee5fe81d5017edcc97f3c007748438                    6011                13654
# ...                                                  ...                  ...
# net.n2works.getsureill                             10570                23029
# nl.mxmx.texttotifinagh                              1195                 2024
# org.adventistas.advcountdown                        9377                21008
# photography.blackgallery.android                   21177                42011
# se.konferensappen.svenskaMoten6                     1650                 3509
#
#                                   ...  top5.Ljava/util/List;  \
# package                           ...
# 09f502a90a61229d76c71907b4f3f74f  ...                      0
# 115e0149ccfeaec1fa1fbd4abbecafeb  ...                      0
# 177af9700bcc8b7c8c131b662e8cdda8  ...                      0
# 17d083988dd5e6d9c2517899ae30bb02  ...                      0
# 23ee5fe81d5017edcc97f3c007748438  ...                      0
# ...                               ...                    ...
# net.n2works.getsureill            ...                      0
# nl.mxmx.texttotifinagh            ...                      0
# org.adventistas.advcountdown      ...                      0
# photography.blackgallery.android  ...                      1
# se.konferensappen.svenskaMoten6   ...                      0
#
#                                   top5.Lkotlin/jvm/internal/Intrinsics;  \
# package
# 09f502a90a61229d76c71907b4f3f74f                                      0
# 115e0149ccfeaec1fa1fbd4abbecafeb                                      0
# 177af9700bcc8b7c8c131b662e8cdda8                                      0
# 17d083988dd5e6d9c2517899ae30bb02                                      0
# 23ee5fe81d5017edcc97f3c007748438                                      0
# ...                                                                 ...
# net.n2works.getsureill                                                0
# nl.mxmx.texttotifinagh                                                0
# org.adventistas.advcountdown                                          1
# photography.blackgallery.android                                      0
# se.konferensappen.svenskaMoten6                                       0
#
#                                   top5.Lmono/android/Runtime;  \
# package
# 09f502a90a61229d76c71907b4f3f74f                            0
# 115e0149ccfeaec1fa1fbd4abbecafeb                            0
# 177af9700bcc8b7c8c131b662e8cdda8                            0
# 17d083988dd5e6d9c2517899ae30bb02                            0
# 23ee5fe81d5017edcc97f3c007748438                            0
# ...                                                       ...
# net.n2works.getsureill                                      0
# nl.mxmx.texttotifinagh                                      0
# org.adventistas.advcountdown                                0
# photography.blackgallery.android                            0
# se.konferensappen.svenskaMoten6                             0
#
#                                   top5.Lmono/android/TypeManager;  \
# package
# 09f502a90a61229d76c71907b4f3f74f                                0
# 115e0149ccfeaec1fa1fbd4abbecafeb                                0
# 177af9700bcc8b7c8c131b662e8cdda8                                0
# 17d083988dd5e6d9c2517899ae30bb02                                0
# 23ee5fe81d5017edcc97f3c007748438                                0
# ...                                                           ...
# net.n2works.getsureill                                          0
# nl.mxmx.texttotifinagh                                          0
# org.adventistas.advcountdown                                    0
# photography.blackgallery.android                                0
# se.konferensappen.svenskaMoten6                                 0
#
#                                   top5.Lorg/apache/cordova/PluginResult;  \
# package
# 09f502a90a61229d76c71907b4f3f74f                                       0
# 115e0149ccfeaec1fa1fbd4abbecafeb                                       0
# 177af9700bcc8b7c8c131b662e8cdda8                                       0
# 17d083988dd5e6d9c2517899ae30bb02                                       0
# 23ee5fe81d5017edcc97f3c007748438                                       0
# ...                                                                  ...
# net.n2works.getsureill                                                 0
# nl.mxmx.texttotifinagh                                                 0
# org.adventistas.advcountdown                                           0
# photography.blackgallery.android                                       0
# se.konferensappen.svenskaMoten6                                        0
#
#                                   top5.Lorg/apache/cordova/inappbrowser/InAppBrowser;  \
# package
# 09f502a90a61229d76c71907b4f3f74f                                                  0
# 115e0149ccfeaec1fa1fbd4abbecafeb                                                  0
# 177af9700bcc8b7c8c131b662e8cdda8                                                  0
# 17d083988dd5e6d9c2517899ae30bb02                                                  0
# 23ee5fe81d5017edcc97f3c007748438                                                  0
# ...                                                                             ...
# net.n2works.getsureill                                                            0
# nl.mxmx.texttotifinagh                                                            0
# org.adventistas.advcountdown                                                      0
# photography.blackgallery.android                                                  0
# se.konferensappen.svenskaMoten6                                                   0
#
#                                   top5.Lorg/aspectj/runtime/reflect/Factory;  \
# package
# 09f502a90a61229d76c71907b4f3f74f                                           0
# 115e0149ccfeaec1fa1fbd4abbecafeb                                           0
# 177af9700bcc8b7c8c131b662e8cdda8                                           0
# 17d083988dd5e6d9c2517899ae30bb02                                           0
# 23ee5fe81d5017edcc97f3c007748438                                           0
# ...                                                                      ...
# net.n2works.getsureill                                                     0
# nl.mxmx.texttotifinagh                                                     0
# org.adventistas.advcountdown                                               0
# photography.blackgallery.android                                           0
# se.konferensappen.svenskaMoten6                                            0
#
#                                   top5.Lorg/json/JSONArray;  \
# package
# 09f502a90a61229d76c71907b4f3f74f                          0
# 115e0149ccfeaec1fa1fbd4abbecafeb                          0
# 177af9700bcc8b7c8c131b662e8cdda8                          0
# 17d083988dd5e6d9c2517899ae30bb02                          0
# 23ee5fe81d5017edcc97f3c007748438                          0
# ...                                                     ...
# net.n2works.getsureill                                    0
# nl.mxmx.texttotifinagh                                    0
# org.adventistas.advcountdown                              0
# photography.blackgallery.android                          0
# se.konferensappen.svenskaMoten6                           0
#
#                                   top5.Lorg/json/JSONException;  \
# package
# 09f502a90a61229d76c71907b4f3f74f                              1
# 115e0149ccfeaec1fa1fbd4abbecafeb                              0
# 177af9700bcc8b7c8c131b662e8cdda8                              0
# 17d083988dd5e6d9c2517899ae30bb02                              0
# 23ee5fe81d5017edcc97f3c007748438                              0
# ...                                                         ...
# net.n2works.getsureill                                        0
# nl.mxmx.texttotifinagh                                        0
# org.adventistas.advcountdown                                  0
# photography.blackgallery.android                              0
# se.konferensappen.svenskaMoten6                               0
#
#                                   top5.Lorg/json/JSONObject;
# package
# 09f502a90a61229d76c71907b4f3f74f                           1
# 115e0149ccfeaec1fa1fbd4abbecafeb                           0
# 177af9700bcc8b7c8c131b662e8cdda8                           0
# 17d083988dd5e6d9c2517899ae30bb02                           0
# 23ee5fe81d5017edcc97f3c007748438                           0
# ...                                                      ...
# net.n2works.getsureill                                     0
# nl.mxmx.texttotifinagh                                     0
# org.adventistas.advcountdown                               0
# photography.blackgallery.android                           0
# se.konferensappen.svenskaMoten6                            0
#
# [70 rows x 70 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
from sklearn.metrics import confusion_matrix, f1_score

# %%
lr_f1 = []
rf_f1 = []
gb_f1 = []
for i in range(1000):
    X_train, X_test, y_train, y_test = train_test_split(
        fb.out, fb.labels == 'class1',
        test_size=0.2
    )
    lr = LogisticRegression(solver='liblinear')
    lr.fit(X_train, y_train)
    lr_f1.append(f1_score(y_test, lr.predict(X_test)))
    
    rf = RandomForestClassifier(n_estimators=10)
    rf.fit(X_train, y_train)
    rf_f1.append(f1_score(y_test, rf.predict(X_test)))

    gb = GradientBoostingClassifier()
    gb.fit(X_train, y_train)
    gb_f1.append(f1_score(y_test, gb.predict(X_test)))
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
np.mean(lr_f1), np.mean(rf_f1), np.mean(gb_f1)
# Out:
# (0.43049323176823173, 0.5942526667776669, 0.6003109170241523)

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
print(lr.score(X_test, y_test))
print(f1_score(y_test, lr.predict(X_test)))
confusion_matrix(y_test, lr.predict(X_test))
# Out:
# 0.5714285714285714
# 0.0
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# array([[8, 2],
#        [4, 0]])

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
print(rf.score(X_test, y_test))
print(f1_score(y_test, rf.predict(X_test)))
confusion_matrix(y_test, rf.predict(X_test))
# Out:
# 0.9285714285714286
# 0.888888888888889
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# array([[9, 1],
#        [0, 4]])

# %%
gb = GradientBoostingClassifier()
gb.fit(X_train, y_train)
print(gb.score(X_test, y_test))
print(f1_score(y_test, gb.predict(X_test)))
confusion_matrix(y_test, gb.predict(X_test))
# Out:
# 0.8571428571428571
# 0.8
# array([[8, 2],
#        [0, 4]])
